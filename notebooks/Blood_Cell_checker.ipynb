# %% [markdown]
# # Blood_Cell_Detective

# %%
import tensorflow as tf

# %%
#cifar = tf.keras.datasets.cifar100
imdb = tf.keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data()
#model = tf.keras.applications.ResNet50(
#    include_top=True,
#    weights=None,
#    input_shape=(32, 32, 3),
#    classes=100,)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model = tf.keras.applications.DenseNet121()
# Out:
# ...
# 33188688/33188688 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_red = x_train[:500]
x_red.shape
# Out:
# (500,)

# %%
y_red = y_train[:500]
y_red.shape
# Out:
# (500,)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_red, y_red, epochs=5, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
#       2 model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
# ----> 3 model.fit(x_red, y_red, epochs=5, batch_size=32)
#
# File ~/.pyenv/versions/3.10.6/envs/tf-metal-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load and preprocess the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize the images

# Build the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the input images
    layers.Dense(128, activation='relu'),  # Add a fully connected layer with 128 units
    layers.Dropout(0.2),  # Add dropout for regularization
    layers.Dense(10, activation='softmax')  # Output layer with 10 units (one for each digit)
])

# Compile the model
model.compile(optimizer='adam',  # Use the Adam optimizer
              loss='sparse_categorical_crossentropy',  # Use sparse categorical crossentropy loss
              metrics=['accuracy'])  # Track accuracy
start_t = time.time()

# Train the model
model.fit(x_train, y_train, epochs=5)  # Train for 5 epochs
# Out:
# /Users/carlobarbini/.pyenv/versions/3.10.6/envs/tf-metal-env/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8529 - loss: 0.4990
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9544 - loss: 0.1473
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9656 - loss: 0.1093
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9732 - loss: 0.0867
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9782 - loss: 0.0714

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc}')

# %% [markdown]
# ## Load data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers, optimizers, callbacks

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img

img = load_img(f"{train_data_dir}cats/cat.3.jpg")
img_arr = img_to_array(img)/255  # We divide the pixel value by 255 to end up between 0 and 1

# %%
# training set has 800 imgs of lymphocytes and 700 imgs equally representing basophils, eosinophils, 
# erythroblasts, igs, neutrophils, monocytes and plateles

# testing set has 400 imgs of lymphocytes and 390 imgs equally representing basophils, eosinophils, 
# erythroblasts, igs, neutrophils, monocytes and plateles

# %%
train_ds = image_dataset_from_directory(
  train_data_dir,
  labels = "inferred",
  label_mode = "binary",
  seed=123,
  image_size=(150, 150),
  batch_size=batch_size)

# We define a second one for the test data

val_ds = image_dataset_from_directory(
  test_data_dir,
  labels = "inferred",
  label_mode = "binary",
  seed=123,
  image_size=(150, 150),
  batch_size=batch_size)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(layers.Rescaling(1./255, input_shape = (150, 150, 3)))
model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model.add(layers.Conv2D(filters = 64, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model.add(layers.Conv2D(filters = 128, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model.add(layers.Flatten())

# Here we flatten our data to end up with just one dimension

model.add(layers.Dense(64, activation="relu"))

model.add(layers.Dropout(0.5))

# And we perform the prediction using sigmoid

model.add(layers.Dense(1, activation="sigmoid"))

# %%
adam = optimizers.Adam(learning_rate = 0.001)
model.compile(loss='binary_crossentropy',
              optimizer= adam,
              metrics=['accuracy'])
